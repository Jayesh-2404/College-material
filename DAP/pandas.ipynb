# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/College-material/DAP/pokemon_data.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Pokemone with the Attack greater than 150
df.loc[df['Attack']>150].shape
# Out:
# (18, 12)

# %%
# Select all pokemons with a Speed of 10 or less
df.loc[df['Speed']<=10]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %%
# How many Pokemons have a Sp. Def value of 25 or less?
df.loc[df['Sp. Def']<=25].shape
# Out:
# (18, 12)

# %%
legendary_df = df.loc[df['Legendary']==True]
legendary_df
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
ax = sns.scatterplot(data = df , x = "Defense", y = "Attack")
ax.annotate(
    "who's that pokemon?" , xy = (228 , 10 ) , xytext = (150  , 10) , color = 'red',
    arrowprops = dict(arrowstyle = '->' , color = 'red')
)
# Out:
# Text(150, 10, "who's that pokemon?")

# %%
df.loc[df['Legendary']].shape
# Out:
# (65, 12)

# %%
df['Legendary'].sum()
# Out:
# 65

# %%
df.sort_values(by = 'Defense').head()
# Out:
#        #       Name    Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113    Chansey    Normal    NaN  250       5        5       35      105
# 488  440    Happiny    Normal    NaN  100       5        5       15       65
# 261  242    Blissey    Normal    NaN  255      10       10       75      135
# 186  172      Pichu  Electric    NaN   20      40       15       35       35
# 188  174  Igglybuff    Normal  Fairy   90      30       15       40       20
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 488     30           4      False
# 261     55           2      False
# 186     60           2      False
# 188     15           2      False

# %%
df.sort_values(by = 'Defense' , ascending=False).head()
# Out:
#        #                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 230  213              Shuckle    Bug    Rock  20      10      230       10
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230       55
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230       60
# 223  208              Steelix  Steel  Ground  75      85      200       55
# 414  377             Regirock   Rock     NaN  80     100      200       50
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 224       95     30           2      False
# 333       80     50           3      False
# 223       65     30           2      False
# 414      100     50           3       True

# %%
df.sort_values(by = ['Defense'  , 'Attack'], ascending=[False ,True]).head()
# Out:
#        #                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 230  213              Shuckle    Bug    Rock  20      10      230       10
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230       55
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230       60
# 223  208              Steelix  Steel  Ground  75      85      200       55
# 414  377             Regirock   Rock     NaN  80     100      200       50
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 224       95     30           2      False
# 333       80     50           3      False
# 223       65     30           2      False
# 414      100     50           3       True

# %%
(
    (df['Type 1']== 'Fire')&
    (df['Type 2']== 'Flying')
).sum()
# Out:
# 6

# %%
True and False
# Out:
# False

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df['Type 2'].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df.query("`Type 1` == 'Poison' or `Type 2` == 'Poison'").shape
# Out:
# (62, 12)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Ice' , 'Defense'].max()
# Out:
# 184

# %%
df.loc[
    (df['Type 1'] == 'Ice')&
    (df['Defense']==df.loc[df['Type 1'] == 'Ice' , 'Defense'].max())
].head()
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 789  713  Avalugg    Ice    NaN  95     117      184       44       46     28
#
#      Generation  Legendary
# 789           6      False

# %%
df.loc[df['Legendary']]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.loc[df['Legendary'] , 'Type 1'].value_counts()
# Out:
# Type 1
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: count, dtype: int64

# %%
df.loc[df['Legendary'] , 'Type 1'].value_counts()
#what if we want first element as output
df.loc[df['Legendary'] , 'Type 1'].value_counts().index[0]
# Out:
# 'Psychic'

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# df.loc[df['Generation']]
#most powerful pokemon in first 3 generation 
df.loc[df['Type 1'] == 'Water'].head()
# Out:
#      #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9    7                 Squirtle  Water    NaN  44      48       65       50
# 10   8                Wartortle  Water    NaN  59      63       80       65
# 11   9                Blastoise  Water    NaN  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59  54                  Psyduck  Water    NaN  50      52       48       65
#
#     Sp. Def  Speed  Generation  Legendary
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 59       50     55           1      False

# %%
df['Generation'].value_counts()
# Basically the syntax id 
#df['Column_Name'].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
df['Generation'].isin([1 , 2 ,3]).sum()
# Out:
# 432

# %%
df.loc[df['Type 1'] == 'Water']['Type 1'].value_counts()
# Out:
# Type 1
# Water    112
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#create the new column in database name "Total " which has count of each type of pokemon
df['Total'] = df['Type 1'].map(df['Type 1'].value_counts())

# %%
#check the count of pokemon name bulbasur
df.loc[df['Name']=='Bulbasaur'].value_counts()
# Out:
# #  Name       Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 1  Bulbasaur  Grass   Poison  45  49      49       65       65       45     1           False      70       1
# Name: count, dtype: int64

# %%
df.loc[
    (df['Type 1'] == 'Water') &
    df['Generation'].isin([1 , 2, 3])
].sort_values(by='Total').head()
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 9      7               Squirtle  Water     NaN   44      48       65       50
# 294  271                 Lombre  Water   Grass   60      50       50       60
# 293  270                  Lotad  Water   Grass   40      30       30       40
# 283  260  SwampertMega Swampert  Water  Ground  100     150      110       95
# 282  260               Swampert  Water  Ground  100     110       90       85
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 9         64     43           1      False    112
# 294       70     50           3      False    112
# 293       50     30           3      False    112
# 283      110     70           3      False    112
# 282       90     60           3      False    112

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.loc[
    ((df['Type 1'] == 'Dragon')| (df['Type 2'] == 'Dragon')) &
    (df['Generation'].isin({5 , 6}))
].sort_values(by='Total' , ascending = False)
# Out:
#        #                Name  Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 767  697           Tyrantrum    Rock    Dragon   82     121      119       69
# 766  696              Tyrunt    Rock    Dragon   58      89       77       45
# 671  610                Axew  Dragon       NaN   46      87       60       30
# 710  646              Kyurem  Dragon       Ice  125     130       90      130
# 776  706              Goodra  Dragon       NaN   90     100       70      110
# 775  705             Sliggoo  Dragon       NaN   68      75       53       83
# 774  704               Goomy  Dragon       NaN   45      50       35       55
# 712  646  KyuremWhite Kyurem  Dragon       Ice  125     120       90      170
# 672  611             Fraxure  Dragon       NaN   66     117       70       40
# 711  646  KyuremBlack Kyurem  Dragon       Ice  125     170      100      120
# 707  644              Zekrom  Dragon  Electric  100     150      120      120
# ...

# %%
df.query("Attack > 100 and `Type 1` =='Fire'")
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 147  136                    Flareon   Fire       NaN   65     130       60
# 263  244                      Entei   Fire       NaN  115     115       85
# 270  250                      Ho-oh   Fire    Flying  106     130       90
# 278  257                   Blaziken   Fire  Fighting   80     120       70
# 279  257      BlazikenMega Blaziken   Fire  Fighting   80     160       80
# 354  323      CameruptMega Camerupt   Fire    Ground   70     120      100
# 437  392                  Infernape   Fire  Fighting   76     104       71
# 559  500                     Emboar   Fire  Fighting  110     123       65
# ...

# %%
water_flying_df = df.query("`Type 1` == 'Water' and `Type 2` == 'Flying' "  )
water_flying_df
# Out:
#        #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 140  130  Gyarados  Water  Flying  95     125       79       60      100
# 244  226   Mantine  Water  Flying  65      40       70       80      140
# 301  278   Wingull  Water  Flying  40      30       30       55       30
# 302  279  Pelipper  Water  Flying  60      50      100       85       70
# 508  458   Mantyke  Water  Flying  45      20       50       60      120
# 641  580  Ducklett  Water  Flying  62      44       50       44       50
# 642  581    Swanna  Water  Flying  75      87       63       87       63
#
#      Speed  Generation  Legendary  Total
# 140     81           1      False    112
# 244     70           2      False    112
# 301     85           3      False    112
# 302     65           3      False    112
# 508     50           4      False    112
# 641     55           5      False    112
# 642     98           5      False    112

# %%
legenedary_fire_df = df.query("`Type 1` == 'Fire' and Legendary == True"), ['Name', 'Attack' ,'Generation']
legenedary_fire_df
# Out:
# (       #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
#  158  146    Moltres   Fire  Flying   90     100       90      125       85
#  263  244      Entei   Fire     NaN  115     115       85       90       75
#  270  250      Ho-oh   Fire  Flying  106     130       90      110      154
#  542  485    Heatran   Fire   Steel   91      90      106      130      106
#  799  721  Volcanion   Fire   Water   80     110      120      130       90
#
#       Speed  Generation  Legendary  Total
#  158     90           1       True     52
#  263    100           2       True     52
#  270     90           2       True     52
#  542     77           4       True     52
#  799     70           6       True     52  ,
#  ['Name', 'Attack', 'Generation'])

# %%
ax = df['Speed'].plot(kind='hist', figsize=(10, 5), bins=100)
ax.axvline(df['Speed'].quantile(.05), color='black')
ax.axvline(df['Speed'].quantile(.95), color='black')

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.scatterplot(data=df, x='Defense', y='Attack', hue='Legendary', ax=ax)
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>
