# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data =  pd.read_csv('D:\College-material\car_insurance_premium_dataset.csv')
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\jayes\AppData\Local\Temp\ipykernel_15196\1067889793.py:1: SyntaxWarning: invalid escape sequence '\C'
#   data =  pd.read_csv('D:\College-material\car_insurance_premium_dataset.csv')
#      Driver Age  Driver Experience  Previous Accidents  \
# 0            56                 32                   4
# 1            46                 19                   0
# 2            32                 11                   4
# 3            60                  0                   4
# 4            25                  7                   0
# ..          ...                ...                 ...
# 995          23                  5                   3
# 996          43                  8                   3
# 997          21                  3                   5
# 998          36                 18                   1
# 999          37                 19                   2
#
# ...

# %%
data.describe()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Driver Age                 1000 non-null   int64
#  1   Driver Experience          1000 non-null   int64
#  2   Previous Accidents         1000 non-null   int64
#  3   Annual Mileage (x1000 km)  1000 non-null   int64
#  4   Car Manufacturing Year     1000 non-null   int64
#  5   Car Age                    1000 non-null   int64
#  6   Insurance Premium ($)      1000 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 54.8 KB

# %%
#how to find null value in dataset 
data.isnull().sum()
#if i have to convert the datatype of particular column
# Out:
# Driver Age                   0
# Driver Experience            0
# Previous Accidents           0
# Annual Mileage (x1000 km)    0
# Car Manufacturing Year       0
# Car Age                      0
# Insurance Premium ($)        0
# dtype: int64

# %%
data['Car Age'] = data['Car Age'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Driver Age                 1000 non-null   int64
#  1   Driver Experience          1000 non-null   int64
#  2   Previous Accidents         1000 non-null   int64
#  3   Annual Mileage (x1000 km)  1000 non-null   int64
#  4   Car Manufacturing Year     1000 non-null   int64
#  5   Car Age                    1000 non-null   int32
#  6   Insurance Premium ($)      1000 non-null   float64
# dtypes: float64(1), int32(1), int64(5)
# memory usage: 50.9 KB

# %%
#drop the column
data.drop('Car Manufacturing Year',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Driver Age                 1000 non-null   int64
#  1   Driver Experience          1000 non-null   int64
#  2   Previous Accidents         1000 non-null   int64
#  3   Annual Mileage (x1000 km)  1000 non-null   int64
#  4   Insurance Premium ($)      1000 non-null   float64
# dtypes: float64(1), int64(4)
# memory usage: 39.2 KB

# %%
data.head()
# Out:
#    Driver Age  Driver Experience  Previous Accidents  \
# 0          56                 32                   4
# 1          46                 19                   0
# 2          32                 11                   4
# 3          60                  0                   4
# 4          25                  7                   0
#
#    Annual Mileage (x1000 km)  Insurance Premium ($)
# 0                         17                 488.35
# 1                         21                 486.15
# 2                         15                 497.55
# 3                         19                 498.35
# 4                         13                 495.55

# %%
#sort by insurance premium
data.sort_values('Insurance Premium ($)',ascending=False)
#apply to all columuns
# Out:
#      Driver Age  Driver Experience  Previous Accidents  \
# 0           112                 64                   8
# 1            92                 38                   0
# 2            64                 22                   8
# 3           120                  0                   8
# 4            50                 14                   0
# ..          ...                ...                 ...
# 995          46                 10                   6
# 996          86                 16                   6
# 997          42                  6                  10
# 998          72                 36                   2
# 999          74                 38                   4
#
#      Annual Mileage (x1000 km)  Insurance Premium ($)
# 0                           34                  976.7
# 1                           42                  972.3
# 2                           30                  995.1
# 3                           38                  996.7
# ...

# %%
data.apply(lambda x: x*2)
# Out:
#      Driver Age  Driver Experience  Previous Accidents  \
# 0           112                 64                   8
# 1            92                 38                   0
# 2            64                 22                   8
# 3           120                  0                   8
# 4            50                 14                   0
# ..          ...                ...                 ...
# 995          46                 10                   6
# 996          86                 16                   6
# 997          42                  6                  10
# 998          72                 36                   2
# 999          74                 38                   4
#
#      Annual Mileage (x1000 km)  Insurance Premium ($)
# 0                           34                  976.7
# 1                           42                  972.3
# 2                           30                  995.1
# 3                           38                  996.7
# ...

# %%
data.nunique()
# Out:
# Driver Age                    48
# Driver Experience             41
# Previous Accidents             6
# Annual Mileage (x1000 km)     15
# Insurance Premium ($)        414
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Driver Age                   0
# Driver Experience            0
# Previous Accidents           0
# Annual Mileage (x1000 km)    0
# Insurance Premium ($)        0
# dtype: int64

# %%
file = pd.read_csv('D:\College-material\india_housing_prices.csv')
file
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\jayes\AppData\Local\Temp\ipykernel_15196\3446734274.py:1: SyntaxWarning: invalid escape sequence '\C'
#   file = pd.read_csv('D:\College-material\india_housing_prices.csv')
#             ID        State       City      Locality      Property_Type  BHK  \
# 0            1   Tamil Nadu    Chennai   Locality_84          Apartment    1
# 1            2  Maharashtra       Pune  Locality_490  Independent House    3
# 2            3       Punjab   Ludhiana  Locality_167          Apartment    2
# 3            4    Rajasthan    Jodhpur  Locality_393  Independent House    2
# 4            5    Rajasthan     Jaipur  Locality_466              Villa    4
# ...        ...          ...        ...           ...                ...  ...
# 249995  249996      Gujarat  Ahmedabad  Locality_187  Independent House    5
# ...

# %%
#what is the map  technique in EDA
#map is used to map the value of one column to another column
#give me some code 
file['State'] = file['State'].map({'M': 'Maharashtra', 'P': 'Punjab'})

# %%
file
# Out:
#             ID State       City      Locality      Property_Type  BHK  \
# 0            1   NaN    Chennai   Locality_84          Apartment    1
# 1            2   NaN       Pune  Locality_490  Independent House    3
# 2            3   NaN   Ludhiana  Locality_167          Apartment    2
# 3            4   NaN    Jodhpur  Locality_393  Independent House    2
# 4            5   NaN     Jaipur  Locality_466              Villa    4
# ...        ...   ...        ...           ...                ...  ...
# 249995  249996   NaN  Ahmedabad  Locality_187  Independent House    5
# 249996  249997   NaN    Chennai  Locality_348          Apartment    1
# 249997  249998   NaN   Warangal  Locality_225              Villa    4
# 249998  249999   NaN    Cuttack  Locality_138              Villa    1
# 249999  250000   NaN    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# ...

# %%
file['status'] = file['Price_in_Lakhs'].map(lambda x: 'Low' if x >= 200 else 'High')

# %%
file
# Out:
#             ID State       City      Locality      Property_Type  BHK  \
# 0            1   NaN    Chennai   Locality_84          Apartment    1
# 1            2   NaN       Pune  Locality_490  Independent House    3
# 2            3   NaN   Ludhiana  Locality_167          Apartment    2
# 3            4   NaN    Jodhpur  Locality_393  Independent House    2
# 4            5   NaN     Jaipur  Locality_466              Villa    4
# ...        ...   ...        ...           ...                ...  ...
# 249995  249996   NaN  Ahmedabad  Locality_187  Independent House    5
# 249996  249997   NaN    Chennai  Locality_348          Apartment    1
# 249997  249998   NaN   Warangal  Locality_225              Villa    4
# 249998  249999   NaN    Cuttack  Locality_138              Villa    1
# 249999  250000   NaN    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# ...

# %%
file.to_csv('D:\College-material\india_housing_prices.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\jayes\AppData\Local\Temp\ipykernel_15196\4234187024.py:1: SyntaxWarning: invalid escape sequence '\C'
#   file.to_csv('D:\College-material\india_housing_prices.csv', index=False)

# %%
file
# Out:
#             ID State       City      Locality      Property_Type  BHK  \
# 0            1   NaN    Chennai   Locality_84          Apartment    1
# 1            2   NaN       Pune  Locality_490  Independent House    3
# 2            3   NaN   Ludhiana  Locality_167          Apartment    2
# 3            4   NaN    Jodhpur  Locality_393  Independent House    2
# 4            5   NaN     Jaipur  Locality_466              Villa    4
# ...        ...   ...        ...           ...                ...  ...
# 249995  249996   NaN  Ahmedabad  Locality_187  Independent House    5
# 249996  249997   NaN    Chennai  Locality_348          Apartment    1
# 249997  249998   NaN   Warangal  Locality_225              Villa    4
# 249998  249999   NaN    Cuttack  Locality_138              Villa    1
# 249999  250000   NaN    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# ...

# %%
#insert the column in the dataset
file.insert(2,'New Column',file['Price_in_Lakhs']*100000)
#insert the rows in the columns and mak
